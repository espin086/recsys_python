# %%
from IMDBData import IMDBData

# %%
clean = IMDBData().get_clean()

# %%
clean
# Out:
#                                   title release_date      budget      revenue  \
# 0                             Toy Story   1995-10-30  30000000.0  373554033.0
# 1                               Jumanji   1995-12-15  65000000.0  262797249.0
# 2                      Grumpier Old Men   1995-12-22         0.0          0.0
# 3                     Waiting to Exhale   1995-12-22  16000000.0   81452156.0
# 4           Father of the Bride Part II   1995-02-10         0.0   76578911.0
# 5                                  Heat   1995-12-15  60000000.0  187436818.0
# 6                               Sabrina   1995-12-15  58000000.0          0.0
# 7                          Tom and Huck   1995-12-22         0.0          0.0
# 8                          Sudden Death   1995-12-22  35000000.0   64350171.0
# 9                             GoldenEye   1995-11-16  58000000.0  352194034.0
# 10               The American President   1995-11-17  62000000.0  107879496.0
# ...
